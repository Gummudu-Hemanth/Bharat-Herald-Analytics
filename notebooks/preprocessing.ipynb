# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
import re

# %% [markdown]
# ### Loading the data

# %%
def import_data(file_path , file_type='auto'):
	try:
		if file_type == 'csv' or file_path.endswith('.csv'):
			return pd.read_csv(file_path)
		else:
			return pd.read_excel(file_path)
	except Exception as e:
		print(f"Error importing {file_path}: {e}")
		raise e
try:
	ad_category_df = pd.read_excel(r'C:\Users\GUMMUDU HEMANTH\Bharat-Herald-Analytics\data_raw\dim_ad_category.xlsx')
	city_df = pd.read_excel(r'C:\Users\GUMMUDU HEMANTH\Bharat-Herald-Analytics\data_raw\dim_city.xlsx')
	ad_revenue_df = pd.read_csv(r'C:\Users\GUMMUDU HEMANTH\Bharat-Herald-Analytics\data_raw\fact_ad_revenue.csv')
	city_readiness_df = pd.read_csv(r'C:\Users\GUMMUDU HEMANTH\Bharat-Herald-Analytics\data_raw\fact_city_readiness.csv')
	digital_plot_df = pd.read_csv(r'C:\Users\GUMMUDU HEMANTH\Bharat-Herald-Analytics\data_raw\fact_digital_pilot.csv')
	print_sales_df = pd.read_excel(r'C:\Users\GUMMUDU HEMANTH\Bharat-Herald-Analytics\data_raw\fact_print_sales.xlsx')

	print("All datasets imported successfully.")

except Exception as e:
	print(f"An error occurred: {e}")
	raise e
# Out:
# All datasets imported successfully.

# %% [markdown]
# ### Data preprocessing

# %%
def data_preprocessing(df, df_name):
	print(f"Preprocessing {df_name}")
	print("\n" + "-"*50 + "\n")

	# Check missing values
	missing_values = df.isnull().sum()
	if missing_values.any():
		print(f"Missing values in {df_name}:{missing_values[missing_values > 0]}")
	else:
		print(f"No missing values in {df_name}.")

	# Check for duplicates
	duplicate_values = df.duplicated().sum()
	if duplicate_values > 0:
		print(f"Found {duplicate_values} duplicate rows in {df_name}.")
	else:
		print(f"No duplicates rows in {df_name}.")

	# Check size of the dataframe
	print(f"{df_name} shape: {df.shape}")

	# Check columns and its data types
	print(f"{df_name} columns and data types:\n{df.dtypes}")

	# Basic statistics for numerical columns
	print(f"Basic statistics for {df_name}:\n{df.describe(include='all')}")
	print("\n" + "="*100 + "\n")


# Preprocess each dataframe
data_preprocessing(ad_category_df, 'ad_category_df')
data_preprocessing(city_df, 'city_df')
data_preprocessing(ad_revenue_df, 'ad_revenue_df')
data_preprocessing(city_readiness_df, 'city_readiness_df')
data_preprocessing(digital_plot_df, 'digital_plot_df')
data_preprocessing(print_sales_df, 'print_sales_df')
# Out:
# Preprocessing ad_category_df
#
# --------------------------------------------------
#
# No missing values in ad_category_df.
# No duplicates rows in ad_category_df.
# ad_category_df shape: (4, 4)
# ad_category_df columns and data types:
# ad_category_id          object
# standard_ad_category    object
# category_group          object
# example_brands          object
# dtype: object
# Basic statistics for ad_category_df:
#        ad_category_id standard_ad_category     category_group example_brands
# count               4                    4                  4              4
# unique              4                    4                  3              4
# top              A001           Government  Commercial Brands       LIC, SBI
# freq                1                    1                  2              1
#
# ====================================================================================================
#
# Preprocessing city_df
#
# --------------------------------------------------
#
# No missing values in city_df.
# No duplicates rows in city_df.
# city_df shape: (10, 4)
# city_df columns and data types:
# city_id    object
# city       object
# state      object
# tier       object
# dtype: object
# Basic statistics for city_df:
#        city_id     city          state    tier
# count       10       10             10      10
# unique      10       10              9       3
# top       C001  lucknow  Uttar Pradesh  Tier 2
# freq         1        1              2       6
#
# ====================================================================================================
#
# Preprocessing ad_revenue_df
#
# --------------------------------------------------
#
# Missing values in ad_revenue_df:comments    682
# dtype: int64
# No duplicates rows in ad_revenue_df.
# ad_revenue_df shape: (720, 6)
# ad_revenue_df columns and data types:
# edition_id      object
# ad_category     object
# quarter         object
# ad_revenue     float64
# currency        object
# comments        object
# dtype: object
# Basic statistics for ad_revenue_df:
#        edition_id ad_category  quarter    ad_revenue currency      comments
# count         720         720      720  7.200000e+02      720            38
# unique         10           4       24           NaN        4             6
# top        ED1005        A001  2023-Q2           NaN      INR  Festive push
# freq           72         215       30           NaN      461             8
# mean          NaN         NaN      NaN  2.221946e+06      NaN           NaN
# std           NaN         NaN      NaN  1.664294e+06      NaN           NaN
# min           NaN         NaN      NaN  1.130500e+04      NaN           NaN
# 25%           NaN         NaN      NaN  5.514449e+04      NaN           NaN
# 50%           NaN         NaN      NaN  2.271604e+06      NaN           NaN
# 75%           NaN         NaN      NaN  3.669045e+06      NaN           NaN
# max           NaN         NaN      NaN  4.998136e+06      NaN           NaN
#
# ====================================================================================================
#
# Preprocessing city_readiness_df
#
# --------------------------------------------------
#
# No missing values in city_readiness_df.
# No duplicates rows in city_readiness_df.
# city_readiness_df shape: (240, 6)
# city_readiness_df columns and data types:
# Unnamed: 0                  int64
# city_id                    object
# quarter                    object
# literacy_rate             float64
# smartphone_penetration    float64
# internet_penetration      float64
# dtype: object
# Basic statistics for city_readiness_df:
#         Unnamed: 0 city_id  quarter  literacy_rate  smartphone_penetration  \
# count    240.00000     240      240     240.000000              240.000000
# unique         NaN      10       24            NaN                     NaN
# top            NaN    C001  2019-Q1            NaN                     NaN
# freq           NaN      24       10            NaN                     NaN
# mean     119.50000     NaN      NaN      76.835583               68.291375
# std       69.42622     NaN      NaN       7.038686               10.542590
# min        0.00000     NaN      NaN      66.110000               45.440000
# 25%       59.75000     NaN      NaN      70.805000               67.625000
# 50%      119.50000     NaN      NaN      75.415000               70.540000
# 75%      179.25000     NaN      NaN      82.782500               76.357500
# max      239.00000     NaN      NaN      89.430000               80.410000
#
#         internet_penetration
# count             240.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean               61.077708
# std                19.029731
# min                10.000000
# 25%                56.447500
# 50%                67.125000
# 75%                74.330000
# max                77.100000
#
# ====================================================================================================
#
# Preprocessing digital_plot_df
#
# --------------------------------------------------
#
# Missing values in digital_plot_df:cumulative_feedback_from_customers    1
# dtype: int64
# No duplicates rows in digital_plot_df.
# digital_plot_df shape: (48, 11)
# digital_plot_df columns and data types:
# Unnamed: 0                              int64
# platform                               object
# launch_month                           object
# ad_category_id                         object
# dev_cost                                int64
# marketing_cost                          int64
# users_reached                           int64
# downloads_or_accesses                   int64
# avg_bounce_rate                       float64
# cumulative_feedback_from_customers     object
# city_id                                object
# dtype: object
# Basic statistics for digital_plot_df:
#         Unnamed: 0           platform launch_month ad_category_id  \
# count        48.00                 48           48             48
# unique         NaN                  4           12              4
# top            NaN  PDF WhatsApp Push      2021-01           A001
# freq           NaN                 12            4             12
# mean         23.50                NaN          NaN            NaN
# std          14.00                NaN          NaN            NaN
# min           0.00                NaN          NaN            NaN
# 25%          11.75                NaN          NaN            NaN
# 50%          23.50                NaN          NaN            NaN
# 75%          35.25                NaN          NaN            NaN
# max          47.00                NaN          NaN            NaN
#
#              dev_cost  marketing_cost  users_reached  downloads_or_accesses  \
# count       48.000000       48.000000      48.000000              48.000000
# unique            NaN             NaN            NaN                    NaN
# top               NaN             NaN            NaN                    NaN
# freq              NaN             NaN            NaN                    NaN
# mean    184276.687500    69980.083333   25671.625000           14225.770833
# std      69989.993082    27382.612710   12833.895367            8903.425273
# min      82023.000000    31651.000000    6619.000000            2880.000000
# 25%     138414.750000    50261.750000   13246.500000            6019.500000
# 50%     184043.500000    65055.500000   23751.500000           13727.000000
# 75%     226451.000000    86073.250000   34309.750000           21454.000000
# max     415324.000000   167913.000000   48619.000000           30763.000000
#
#         avg_bounce_rate                 cumulative_feedback_from_customers  \
# count         48.000000                                                 47
# unique              NaN                                                  3
# top                 NaN  Mixed feedback: some usability concerns, but h...
# freq                NaN                                                 44
# mean          65.767292                                                NaN
# std           14.452675                                                NaN
# min           41.360000                                                NaN
# 25%           52.397500                                                NaN
# 50%           66.070000                                                NaN
# 75%           78.030000                                                NaN
# max           89.250000                                                NaN
#
#        city_id
# count       48
# unique      10
# top       C001
# freq         5
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
#
# ====================================================================================================
#
# Preprocessing print_sales_df
#
# --------------------------------------------------
#
# No missing values in print_sales_df.
# No duplicates rows in print_sales_df.
# print_sales_df shape: (720, 8)
# print_sales_df columns and data types:
# edition_ID         object
# City_ID            object
# Language           object
# State              object
# Month              object
# Copies Sold        object
# copies_returned     int64
# Net_Circulation     int64
# dtype: object
# Basic statistics for print_sales_df:
#        edition_ID City_ID Language      State                Month  \
# count         720     720      720        720                  720
# unique         10      10        4         10                   77
# top        ED1005    C005    Hindi  Rajasthan  2023-05-01 00:00:00
# freq           72      72      504         72                   10
# mean          NaN     NaN      NaN        NaN                  NaN
# std           NaN     NaN      NaN        NaN                  NaN
# min           NaN     NaN      NaN        NaN                  NaN
# 25%           NaN     NaN      NaN        NaN                  NaN
# 50%           NaN     NaN      NaN        NaN                  NaN
# 75%           NaN     NaN      NaN        NaN                  NaN
# max           NaN     NaN      NaN        NaN                  NaN
#
#         Copies Sold  copies_returned  Net_Circulation
# count         720.0       720.000000       720.000000
# unique        719.0              NaN              NaN
# top        420921.0              NaN              NaN
# freq            2.0              NaN              NaN
# mean            NaN     16430.815278    287950.551389
# std             NaN      6524.459623     83191.491771
# min             NaN      4991.000000    139098.000000
# 25%             NaN     11379.500000    219982.750000
# 50%             NaN     15151.000000    279778.000000
# 75%             NaN     20902.250000    351736.750000
# max             NaN     38021.000000    487255.000000
#
# ====================================================================================================

# %% [markdown]
# ### Handling Missing Values

# %%
def handling_missing_values(ad_revenue_df , digital_plot_df):
	# Handling missing values in ad_revenue_df
	ad_revenue_df['comments'] = ad_revenue_df['comments'].fillna('No Commensts')

	# Handling missing values in digital_plot_df
	digital_plot_df['cumulative_feedback_from_customers'] = digital_plot_df['cumulative_feedback_from_customers'].fillna(method='ffill')

	return ad_revenue_df , digital_plot_df

ad_revenue_df , digital_plot_df = handling_missing_values(ad_revenue_df , digital_plot_df)

# %% [markdown]
# ### Handling Inconsistencies in Ad_Revenue_Df Table

# %%
ad_revenue_df.sample(10)
# Out:
#     edition_id ad_category       quarter  ad_revenue   currency      comments
# 259     ED1006        A002       Q3-2020    15537.52        EUR  No Commensts
# 351     ED1001        A003       Q3-2020  3607897.00  IN RUPEES  No Commensts
# 442     ED1007        A002       Q1-2023  1421291.00  IN RUPEES  No Commensts
# 260     ED1005        A003       Q3-2022  2724025.00        INR  No Commensts
# 239     ED1010        A004       Q1-2019  1241017.00        INR  No Commensts
# 463     ED1009        A003       2022-Q2  1813467.00        INR  No Commensts
# 690     ED1001        A004  4th Qtr 2020  1635330.00        INR  No Commensts
# 534     ED1007        A003       Q3-2019  1040707.00        INR  No Commensts
# 530     ED1006        A003       2022-Q2  2973670.00        INR  No Commensts
# 309     ED1006        A004       2023-Q2    38727.36        USD  No Commensts

# %%
def preprocess_ad_revenue(ad_revenue_df):
	# Create a copy
	ad_revenue_df_copy = ad_revenue_df.copy()

	# Standardize Quarter Column
	ad_revenue_df_copy['year'] = ad_revenue_df_copy['quarter'].str.extract(r'(\d{4})')
	ad_revenue_df_copy['quarter_num'] = ad_revenue_df_copy['quarter'].str.extract(r'([Qq]\d|Qtr\d|[1-4]th\s*Qtr)', flags=re.IGNORECASE)
	ad_revenue_df_copy['quarter_num'] = ad_revenue_df_copy['quarter_num'].str.replace('[^0-9]', '', regex=True)

	# Standardize ad_revenue and currency column
	usd_to_inr = 88.14
	eur_to_inr = 103.39

	ad_revenue_df_copy['currency'] = ad_revenue_df_copy['currency'].str.upper().str.strip()

	# Conditions for each currency type
	conditions = [
		ad_revenue_df_copy['currency'].isin(['INR' , 'IN RUPEES']),
		ad_revenue_df_copy['currency'] == 'USD',
		ad_revenue_df_copy['currency'] == 'EUR'
	]

	# Corresponding choices for each condition
	choices = [
		ad_revenue_df_copy['ad_revenue'],
		ad_revenue_df_copy['ad_revenue'] * usd_to_inr,
		ad_revenue_df_copy['ad_revenue'] * eur_to_inr
	]

	ad_revenue_df_copy['ad_revenue_inr'] = np.select(conditions, choices, default=np.nan)
	ad_revenue_df_copy['ad_revenue_inr'] = ad_revenue_df_copy['ad_revenue_inr'].round(2)
	return ad_revenue_df_copy

ad_revenue_df = preprocess_ad_revenue(ad_revenue_df)

# %%
ad_revenue_df.head()
# Out:
#   edition_id ad_category       quarter  ad_revenue currency      comments  \
# 0     ED1005        A001       2023-Q2    22613.69      EUR  No Commensts
# 1     ED1005        A002       Q1-2019    39366.88      USD  No Commensts
# 2     ED1001        A003       Q3-2023  3709860.00      INR  No Commensts
# 3     ED1003        A002       Q3-2023    40969.55      USD  No Commensts
# 4     ED1007        A003  4th Qtr 2020    51779.40      USD  No Commensts
#
#    year quarter_num  ad_revenue_inr
# 0  2023           2      2338029.41
# 1  2019           1      3469796.80
# 2  2023           3      3709860.00
# 3  2023           3      3611056.14
# 4  2020           4      4563836.32

# %% [markdown]
# ### Handling Inconsistencies in Digital Plot table

# %%
digital_plot_df.sample(10)
# Out:
#     Unnamed: 0                platform launch_month ad_category_id  dev_cost  \
# 31          31         Mobile App Beta      2021-08           A002    193175
# 28          28         Mobile App Beta      2021-05           A002     89596
# 3            3       PDF WhatsApp Push      2021-04           A001    147695
# 26          26         Mobile App Beta      2021-03           A002    162617
# 17          17      E-paper Mobile Web      2021-06           A003    338339
# 42          42  Responsive Web Version      2021-07           A004    184195
# 7            7       PDF WhatsApp Push      2021-08           A001    188777
# 11          11       PDF WhatsApp Push      2021-12           A001    106832
# 34          34         Mobile App Beta      2021-11           A002    153445
# 16          16      E-paper Mobile Web      2021-05           A003    169464
#
#     marketing_cost  users_reached  downloads_or_accesses  avg_bounce_rate  \
# 31           58854          24715                   8189            52.93
# 28           40258          30279                  26586            42.60
# 3            78868          46796                  15640            66.17
# 26           43428          47963                  15016            80.32
# 17           82663          26785                   4784            77.80
# 42           89792          22069                  19491            62.56
# 7            66727          39865                  17866            76.14
# 11           44226          37373                  28240            44.09
# 34           31651          10105                   7462            77.84
# 16           35997          28284                   9055            82.50
#
#                    cumulative_feedback_from_customers city_id
# 31  Mixed feedback: some usability concerns, but h...    C002
# 28  Mixed feedback: some usability concerns, but h...    C009
# 3   Mixed feedback: some usability concerns, but h...    C004
# 26  Mixed feedback: some usability concerns, but h...    C007
# 17  Many said font was too tiny to read.\nZooming ...    C008
# 42  Mixed feedback: some usability concerns, but h...    C003
# 7   Mixed feedback: some usability concerns, but h...    C008
# 11  Mixed feedback: some usability concerns, but h...    C002
# 34  Mixed feedback: some usability concerns, but h...    C005
# 16  Mixed feedback: some usability concerns, but h...    C007

# %%
def preprocess_digital_plot(digital_plot_df):
	# Create a copy
	digital_plot_df_copy = digital_plot_df.copy()

	# Convert 'launch_month' to datetime
	digital_plot_df_copy['launch_month'] = pd.to_datetime(digital_plot_df_copy['launch_month'], errors='coerce')

	# Extract year , month , month_name and quarter
	digital_plot_df_copy['launch_year'] = digital_plot_df_copy['launch_month'].dt.year
	digital_plot_df_copy['launch_month_num'] = digital_plot_df_copy['launch_month'].dt.month
	digital_plot_df_copy['launch_month_name'] = digital_plot_df_copy['launch_month'].dt.month_name()
	digital_plot_df_copy['launch_quarter'] = digital_plot_df_copy['launch_month'].dt.quarter

	return digital_plot_df_copy

digital_plot_df_test = preprocess_digital_plot(digital_plot_df)

# %%
digital_plot_df_test.sample(10)
# Out:
#     Unnamed: 0                platform launch_month ad_category_id  dev_cost  \
# 2            2       PDF WhatsApp Push   2021-03-01           A001    242728
# 42          42  Responsive Web Version   2021-07-01           A004    184195
# 28          28         Mobile App Beta   2021-05-01           A002     89596
# 18          18      E-paper Mobile Web   2021-07-01           A003    226451
# 1            1       PDF WhatsApp Push   2021-02-01           A001    156865
# 44          44  Responsive Web Version   2021-09-01           A004    248876
# 12          12      E-paper Mobile Web   2021-01-01           A003    195725
# 39          39  Responsive Web Version   2021-04-01           A004    262756
# 37          37  Responsive Web Version   2021-02-01           A004    199654
# 9            9       PDF WhatsApp Push   2021-10-01           A001    221877
#
#     marketing_cost  users_reached  downloads_or_accesses  avg_bounce_rate  \
# 2            46087           8471                   2891            68.06
# 42           89792          22069                  19491            62.56
# 28           40258          30279                  26586            42.60
# 18           85506          22833                   7708            73.45
# 1            99122          19472                  17017            82.53
# 44           64051          42051                  21433            78.60
# 12           93646          40525                  23092            62.92
# 39          167913          16821                   5065            81.30
# 37           57386           8384                   5805            83.89
# 9            95697          47845                  21517            75.39
#
#                    cumulative_feedback_from_customers city_id  launch_year  \
# 2   Mixed feedback: some usability concerns, but h...    C003         2021
# 42  Mixed feedback: some usability concerns, but h...    C003         2021
# 28  Mixed feedback: some usability concerns, but h...    C009         2021
# 18  Mixed feedback: some usability concerns, but h...    C009         2021
# 1   Mixed feedback: some usability concerns, but h...    C002         2021
# 44  Mixed feedback: some usability concerns, but h...    C005         2021
# 12  Mixed feedback: some usability concerns, but h...    C003         2021
# 39  Mixed feedback: some usability concerns, but h...    C010         2021
# 37  Mixed feedback: some usability concerns, but h...    C008         2021
# 9   Mixed feedback: some usability concerns, but h...    C010         2021
#
#     launch_month_num launch_month_name  launch_quarter
# 2                  3             March               1
# 42                 7              July               3
# 28                 5               May               2
# 18                 7              July               3
# 1                  2          February               1
# 44                 9         September               3
# 12                 1           January               1
# 39                 4             April               2
# 37                 2          February               1
# 9                 10           October               4

# %% [markdown]
# ### Handling Inconsistencies in City Readiness Table

# %%
city_readiness_df.sample(10)
# Out:
#      Unnamed: 0 city_id  quarter  literacy_rate  smartphone_penetration  \
# 35           35    C002  2021-Q4          71.13                   48.21
# 43           43    C002  2023-Q4          70.58                   47.84
# 192         192    C009  2019-Q1          75.15                   67.85
# 96           96    C005  2019-Q1          84.85                   70.31
# 64           64    C003  2023-Q1          82.81                   72.07
# 236         236    C010  2024-Q1          70.77                   77.29
# 219         219    C010  2019-Q4          70.59                   76.21
# 112         112    C005  2023-Q1          84.60                   70.42
# 153         153    C007  2021-Q2          66.24                   77.10
# 176         176    C008  2021-Q1          71.19                   79.99
#
#      internet_penetration
# 35                  50.41
# 43                  47.76
# 192                 76.09
# 96                  10.00
# 64                  66.71
# 236                 74.30
# 219                 75.06
# 112                 10.00
# 153                 63.71
# 176                 74.27

# %%
def preprocess_city_readiness(city_readiness_df):
	# Create a copy
	city_readiness_df_copy = city_readiness_df.copy()

	# Extract year and quarter_num from Quarter Column
	city_readiness_df_copy['year'] = city_readiness_df_copy['quarter'].str.extract(r'(\d{4})')
	city_readiness_df_copy['quarter_num'] = city_readiness_df_copy['quarter'].str.extract(r'([Qq]\d|Qtr\d|[1-4]th\s*Qtr)', flags=re.IGNORECASE)
	city_readiness_df_copy['quarter_num'] = city_readiness_df_copy['quarter_num'].str.replace('[^0-9]', '', regex=True)

	return city_readiness_df_copy

city_readiness_df = preprocess_city_readiness(city_readiness_df)

# %%
city_readiness_df.sample(10)
# Out:
#      Unnamed: 0 city_id  quarter  literacy_rate  smartphone_penetration  \
# 57           57    C003  2021-Q2          82.65                   69.86
# 71           71    C003  2024-Q4          82.74                   68.67
# 223         223    C010  2020-Q4          70.68                   75.74
# 62           62    C003  2022-Q3          82.78                   70.32
# 165         165    C007  2024-Q2          66.76                   75.45
# 10           10    C001  2021-Q3          89.14                   75.25
# 90           90    C004  2023-Q3          75.60                   67.46
# 229         229    C010  2022-Q2          70.75                   76.34
# 219         219    C010  2019-Q4          70.59                   76.21
# 59           59    C003  2021-Q4          82.82                   70.76
#
#      internet_penetration  year quarter_num
# 57                  66.96  2021           2
# 71                  67.15  2024           4
# 223                 73.71  2020           4
# 62                  67.08  2022           3
# 165                 62.79  2024           2
# 10                  55.16  2021           3
# 90                  67.99  2023           3
# 229                 74.27  2022           2
# 219                 75.06  2019           4
# 59                  66.48  2021           4

# %%
city_readiness_df.isna().sum()
# Out:
# Unnamed: 0                0
# city_id                   0
# quarter                   0
# literacy_rate             0
# smartphone_penetration    0
# internet_penetration      0
# year                      0
# quarter_num               0
# dtype: int64

# %% [markdown]
# ### Handling Inconsistencies in Print Sales Table

# %%
print_sales_df.head()
# Out:
#   edition_ID City_ID Language           State                Month  \
# 0     ED1005    C005    Hindi       Rajasthan  2023-05-01 00:00:00
# 1     ED1005    C005    Hindi       Rajasthan  2019-03-01 00:00:00
# 2     ED1001    C001    hindi   Uttar pradesh  2023-07-01 00:00:00
# 3     ED1003    C003    Hindi  Madhya_Pradesh  2023-07-01 00:00:00
# 4     ED1007    C007    Hindi       Jharkhand  2020-10-01 00:00:00
#
#   Copies Sold  copies_returned  Net_Circulation
# 0      404389            13510           390879
# 1      492943            25024           467919
# 2      168893            12285           156608
# 3      216540            10117           206423
# 4      234563            13048           221515

# %%
print_sales_df['State'].unique()
# Out:
# array(['Rajasthan', 'Uttar pradesh', 'Madhya_Pradesh', 'Jharkhand',
#        'maharashtra', 'Uttar-Pradesh', 'Delhi', 'gujarat', 'bihar',
#        'Uttar Pradesh'], dtype=object)

# %%
def preprocess_print_sales(print_sales_df):
	# Create a copy
	print_sales_df_copy = print_sales_df.copy()

	print_sales_df_copy['State'] = print_sales_df_copy['State'].str.replace(r'Uttar-Pradesh|Uttar pradesh', 'Uttar Pradesh', regex=True)
	print_sales_df_copy.rename(columns={'Copies Sold': 'Copies_Sold'}, inplace=True)
	# Convert Month to datetime
	print_sales_df_copy['Month'] = pd.to_datetime(print_sales_df_copy['Month'], errors='coerce')

	# Extract year , month , month_name and quarter
	print_sales_df_copy['year'] = print_sales_df_copy['Month'].dt.year
	print_sales_df_copy['month_num'] = print_sales_df_copy['Month'].dt.month
	print_sales_df_copy['month_name'] = print_sales_df_copy['Month'].dt.month_name()
	print_sales_df_copy['quarter'] = print_sales_df_copy['Month'].dt.quarter

	return print_sales_df_copy

print_sales_df = preprocess_print_sales(print_sales_df)

# %%
print_sales_df.sample(10)
# Out:
#     edition_ID City_ID Language          State      Month Copies_Sold  \
# 627     ED1010    C010    Hindi  Uttar Pradesh 2023-04-01      400526
# 494     ED1001    C001    hindi  Uttar Pradesh 2023-12-01      167015
# 173     ED1007    C007    Hindi      Jharkhand 2024-08-01      192417
# 600     ED1009    C009    Hindi        gujarat 2021-09-01      284447
# 34      ED1008    C008    Hindi  Uttar Pradesh 2024-08-01      283139
# 148     ED1001    C001    hindi  Uttar Pradesh 2023-09-01      163687
# 324     ED1008    C008    Hindi  Uttar Pradesh 2021-10-01      332029
# 616     ED1007    C007    Hindi      Jharkhand 2023-10-01      194458
# 680     ED1008    C008    Hindi  Uttar Pradesh 2024-03-01   â‚¹284706
# 651     ED1008    C008    Hindi  Uttar Pradesh 2024-02-01      284638
#
#      copies_returned  Net_Circulation  year  month_num month_name  quarter
# 627            25275           375251  2023          4      April        2
# 494             9768           157247  2023         12   December        4
# 173             7528           184889  2024          8     August        3
# 600            21726           262721  2021          9  September        3
# 34             21735           261404  2024          8     August        3
# 148             5466           158221  2023          9  September        3
# 324            20139           311890  2021         10    October        4
# 616             7833           186625  2023         10    October        4
# 680            20245           264461  2024          3      March        1
# 651            12119           272519  2024          2   February        1

# %% [markdown]
# ### Storing the cleaned datasets for futher analysis.

# %%
# Path of the current directory
current_dir = Path.cwd()

# Move to Bharat-Herald-Analytics directory
main_dir = current_dir.parent

# Define paths for cleaned data
cleaned_data_dir = main_dir / 'data_cleaned'

# Create the directory if it doesn't exist
cleaned_data_dir.mkdir(parents=True, exist_ok=True)

print("Directory for cleaned data is set up at:", cleaned_data_dir)
# Out:
# Directory for cleaned data is set up at: c:\Users\GUMMUDU HEMANTH\Bharat-Herald-Analytics\data_cleaned

# %%
city_df.to_excel(cleaned_data_dir / 'cleaned_city_data.xlsx', index=False)
ad_revenue_df.to_csv(cleaned_data_dir / 'cleaned_ad_revenue.csv', index=False)
city_readiness_df.to_csv(cleaned_data_dir / 'cleaned_city_readiness.csv', index=False)
digital_plot_df.to_csv(cleaned_data_dir / 'cleaned_digital_plot.csv', index=False)
print_sales_df.to_excel(cleaned_data_dir / 'cleaned_print_sales.xlsx', index=False)
ad_category_df.to_excel(cleaned_data_dir / 'cleaned_ad_category.xlsx', index=False)
print("Cleaned datasets have been saved successfully.")
# Out:
# Cleaned datasets have been saved successfully.
